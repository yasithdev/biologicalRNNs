# %% [markdown]
# #### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
from tqdm import tqdm

# %%
from numpy.linalg import eig, svd
from sklearn.decomposition import PCA

# %%
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset
from torchvision import datasets, transforms

from torch.optim.lr_scheduler import StepLR, CosineAnnealingLR

# %%
from data_loader import makeTensorLoaders

# %% [markdown]
# #### Test for CUDA

# %%
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('No GPU, training on CPU')
    device = torch.device('cpu')
else:
    print('GPU found, training on GPU')
    device = torch.device('cuda')
# Out:
# GPU found, training on GPU

# %% [markdown]
# #### Simulation parameters

# %%
N = 128 ## number of recurrent neurons
nsecs = 50 ## time
n_channels = 1

# %%
nRuns = 5

# %% [markdown]
# #### Train and test datasets

# %%
def random_assignment(numSamps, n, p):
    # Create a zero array of shape (numSamps, n)
    arr = np.random.choice([-1, 1], size=(numSamps, n))
    
    # Randomly assign 1 or -1 to elements with probability p
    rand_arr = np.random.random(arr.shape)
    arr[np.random.random(arr.shape) > p] = 0
    
    return arr

# %%
nTrain = 6000
nTest = 1000
prob_delta = 0.05

# %%
batch_size = 200

# %%
def flipflop_output(input_array):
    output_array = np.zeros_like(input_array)
    current_state = 0  # Track the current state
    
    for tt in range(len(input_array)):
        if input_array[tt] !=0:
            current_state = input_array[tt]
            output_array[tt:] = current_state
            
    return output_array

# %%
data_in_train = {}
data_in_test = {}

# %%
data_out_train = {}
data_out_test = {}

# %%
for cntr in range(nRuns):
    data_in_train[cntr] = random_assignment(nTrain, nsecs, prob_delta)
    data_in_test[cntr] = random_assignment(nTest, nsecs, prob_delta)
    
    data_out_train[cntr] = np.zeros_like(data_in_train[cntr])
    data_out_test[cntr] = np.zeros_like(data_in_test[cntr])
    
    for ii in range(nTrain):
        data_out_train[cntr][ii] = flipflop_output(data_in_train[cntr][ii])
        
    for ii in range(nTest):
        data_out_test[cntr][ii] = flipflop_output(data_in_test[cntr][ii])

# %%
train_loader = {}
test_loader = {}

# %%
for cntr in range(nRuns):
    train_loader[cntr] = makeTensorLoaders((data_in_train[cntr], data_out_train[cntr]), batch_size, shuffle=True)
    test_loader[cntr] = makeTensorLoaders((data_in_test[cntr], data_out_test[cntr]), batch_size, shuffle=False)

# %% [markdown]
# #### Model and other hyper-params

# %%
num_layers = 1
input_size = n_channels
hidden_size = N
output_size = input_size

# %%
def initialize_weights(N, index_ranges, signs):
    weights = np.zeros((N, N))
    for ii, (start, end) in enumerate(index_ranges):
        limit = 1 / np.sqrt(N) if signs[ii] == 1 else -1/np.sqrt(N)
        weights[:, start:end] = np.random.uniform(0, limit, size=(N, end-start))
    return weights

# %%
def generate_mask(weights, index_ranges, signs):
    mask = np.zeros_like(weights)
    for i, (start, end) in enumerate(index_ranges):
        if signs[i] == 1:
            mask[:, start:end] = np.where(weights[:, start:end] > 0, 1, 0)
        elif signs[i] == -1:
            mask[:, start:end] = np.where(weights[:, start:end] < 0, 1, 0)
    return mask

# %%
# Define the neural network
class SimpleRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, device):
        
        super(SimpleRNN, self).__init__()
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, num_layers=1, batch_first=True, nonlinearity='tanh')
        self.fc = nn.Linear(hidden_size, output_size)
        self.output_size = output_size
        self.device = device

    def forward(self, x):
        m = nn.Tanh()
        h0 = torch.zeros(1, x.size(0), self.hidden_size).to(x.device)
        nSamp, nSteps, inDim = x.shape
        
        ops = torch.zeros(nSamp,nSteps,self.hidden_size, requires_grad=False).to(self.device)
        pred = torch.zeros(nSamp,nSteps,self.output_size, requires_grad=False).to(self.device)
        
        for ii in range(nSteps):
            ip = torch.unsqueeze(x[:,ii,:],1)
            op, ht = self.rnn(ip,h0) ## pass 1 timestep through RNN
#             fr_mask = ht.clone()>0
#             htt = fr_mask*ht.clone() ## mask firing rate
            h0 = ht ## update hidden state
            ops[:,ii,:] = torch.squeeze(op.clone())

            ## Final prediction at every timestep
            pred[:,ii,:] = m(self.fc(ops[:, ii, :].clone()))
        
        return pred, ht

# %%
frac_ex = 0.8
frac_in = 1-frac_ex

# %%
signs = [1,-1]
index_ranges = [(0,int(N*frac_ex)),(int(N*frac_ex),N)]

# %%
# Initialize the model
model = {}
weights_init = {}

# %%
for cntr in range(nRuns):
    model[cntr] = SimpleRNN(input_size, hidden_size, output_size, device).to(device)
    weights_init[cntr] = initialize_weights(N,index_ranges,signs)
    model[cntr].rnn.weight_hh_l0.data = torch.from_numpy(weights_init[cntr]).float().to(device)

# %%
pp = 1.0
conn_mask = {}
sign_mask = {}
full_mask = {}

# %%
for cntr in range(nRuns):
    conn_mask[cntr] = np.random.choice([0, 1], size=(N,N), p=[1-pp, pp])
    sign_mask[cntr] = np.sign(weights_init[cntr])
    sign_mask[cntr][sign_mask[cntr] == 0] = 1
    full_mask[cntr] = torch.from_numpy(sign_mask[cntr]*conn_mask[cntr]).float().to(device)

# %%
kk = 0

plt.imshow(weights_init[kk])
plt.colorbar()
plt.title('Initial Weights: Conventional Backprop')
# Out:
# Text(0.5, 1.0, 'Initial Weights: Conventional Backprop')

# %%
plt.hist(weights_init[kk])
plt.title('Distribution of Weights: Conventional Backprop')
plt.xlabel('Weights')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# #### Model training

# %%
num_epochs = 100
learning_rate = 0.001

# %%
criterion = nn.MSELoss()

optimizer = {}
for cntr in range(nRuns):
    optimizer[cntr] = optim.Adam(model[cntr].parameters(), lr=learning_rate)

# %%
train_losses = np.zeros((nRuns, num_epochs))
test_losses = np.zeros((nRuns, num_epochs))

# %%
for run in tqdm(range(nRuns)):
    model[run].train()
    train_loss_min = np.Inf
    
    for epoch in range(1, num_epochs+1):
        print('Epoch: ',epoch)

        train_loss = 0.0
        test_loss = 0.0
        
        for inputs, targets in train_loader[run]:
            if train_on_gpu:
                inputs, targets = torch.unsqueeze(inputs.float().cuda(),-1), torch.unsqueeze(targets.float().cuda(),-1)
                model[run].cuda()
            else:
                inputs, targets = torch.unsqueeze(inputs.float(),-1), torch.unsqueeze(targets.float(),-1)

            optimizer[run].zero_grad()
            outputs, firing_rates = model[run](inputs)
            if train_on_gpu:
                outputs = outputs.cuda()
            loss = criterion(outputs, targets)
            train_loss += loss.item()

            loss.backward()
            optimizer[run].step()

            ## Rectify weights
#             w = model[run].rnn.weight_hh_l0.detach().cpu().numpy()
#             w[w < 0] = 0
#             model[run].rnn.weight_hh_l0.data = torch.from_numpy(w).float().to(device)
            
            ## Apply mask
#             model[run].rnn.weight_hh_l0.data = full_mask[run]*model[run].rnn.weight_hh_l0.data

        if train_loss< train_loss_min:
            print('Epoch: {}, Train Loss Decreased!! ({:.6f}-->{:.6f})'.format(epoch,train_loss_min,train_loss))
            train_loss_min = train_loss
        
        train_losses[run][epoch-1] = train_loss

        for inputs_test, targets_test in test_loader[run]:
            if train_on_gpu:
                inputs_test, targets_test = torch.unsqueeze(inputs_test.float().cuda(),-1), torch.unsqueeze(targets_test.float().cuda(),-1)
                model[run].cuda()
            else:
                inputs_test, targets_test = torch.unsqueeze(inputs_test.float(),-1), torch.unsqueeze(targets_test.float(),-1)

            outputs_test, firing_rates_test = model[run](inputs_test)
            if train_on_gpu:
                outputs_test = outputs_test.cuda()
            loss_test = criterion(outputs_test, targets_test)
            test_loss += loss_test.item()
            
        test_losses[run][epoch-1] = test_loss

        print('Epoch: {}, Test Loss({:.6f})'.format(epoch,test_loss))
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch:  1
# Epoch: 1, Train Loss Decreased!! (inf-->20.369992)
# Epoch: 1, Test Loss(3.243170)
# Epoch:  2
# Epoch: 2, Train Loss Decreased!! (20.369992-->19.669825)
# Epoch: 2, Test Loss(3.216419)
# Epoch:  3
# Epoch: 3, Train Loss Decreased!! (19.669825-->19.624241)
# Epoch: 3, Test Loss(3.207168)
# Epoch:  4
# Epoch: 4, Train Loss Decreased!! (19.624241-->19.518619)
# Epoch: 4, Test Loss(3.187663)
# Epoch:  5
# Epoch: 5, Test Loss(3.100162)
# Epoch:  6
# Epoch: 6, Train Loss Decreased!! (19.518619-->19.494702)
# Epoch: 6, Test Loss(3.181581)
# Epoch:  7
# Epoch: 7, Train Loss Decreased!! (19.494702-->18.949084)
# Epoch: 7, Test Loss(2.959121)
# Epoch:  8
# Epoch: 8, Train Loss Decreased!! (18.949084-->17.913482)
# Epoch: 8, Test Loss(2.822963)
# Epoch:  9
# Epoch: 9, Train Loss Decreased!! (17.913482-->17.117382)
# Epoch: 9, Test Loss(3.073046)
# Epoch:  10
# Epoch: 10, Train Loss Decreased!! (17.117382-->15.860724)
# Epoch: 10, Test Loss(5.383688)
# Epoch:  11
# Epoch: 11, Test Loss(3.218145)
# Epoch:  12
# Epoch: 12, Test Loss(3.107983)
# Epoch:  13
# Epoch: 13, Test Loss(3.079794)
# Epoch:  14
# Epoch: 14, Test Loss(3.022460)
# Epoch:  15
# Epoch: 15, Test Loss(2.879825)
# Epoch:  16
# Epoch: 16, Test Loss(2.488991)
# Epoch:  17
# Epoch: 17, Test Loss(3.155497)
# Epoch:  18
# Epoch: 18, Test Loss(2.732480)
# Epoch:  19
# Epoch: 19, Test Loss(5.480640)
# Epoch:  20
# Epoch: 20, Test Loss(3.208023)
# Epoch:  21
# Epoch: 21, Test Loss(3.012330)
# Epoch:  22
# Epoch: 22, Test Loss(2.829058)
# Epoch:  23
# Epoch: 23, Train Loss Decreased!! (15.860724-->15.157602)
# Epoch: 23, Test Loss(5.523000)
# Epoch:  24
# Epoch: 24, Test Loss(2.735139)
# Epoch:  25
# Epoch: 25, Train Loss Decreased!! (15.157602-->13.280038)
# Epoch: 25, Test Loss(1.166724)
# Epoch:  26
# Epoch: 26, Train Loss Decreased!! (13.280038-->9.479194)
# Epoch: 26, Test Loss(1.598028)
# Epoch:  27
# Epoch: 27, Test Loss(1.509804)
# Epoch:  28
# Epoch: 28, Test Loss(2.055397)
# Epoch:  29
# Epoch: 29, Test Loss(1.099177)
# Epoch:  30
# Epoch: 30, Train Loss Decreased!! (9.479194-->5.492804)
# Epoch: 30, Test Loss(1.065760)
# Epoch:  31
# Epoch: 31, Train Loss Decreased!! (5.492804-->4.559855)
# Epoch: 31, Test Loss(1.388259)
# Epoch:  32
# Epoch: 32, Test Loss(0.686168)
# Epoch:  33
# Epoch: 33, Test Loss(0.621156)
# Epoch:  34
# Epoch: 34, Test Loss(0.707111)
# Epoch:  35
# Epoch: 35, Test Loss(6.299425)
# Epoch:  36
# Epoch: 36, Test Loss(3.241533)
# Epoch:  37
# Epoch: 37, Test Loss(3.075625)
# Epoch:  38
# Epoch: 38, Test Loss(3.026597)
# Epoch:  39
# Epoch: 39, Test Loss(3.009241)
# Epoch:  40
# Epoch: 40, Test Loss(2.904072)
# Epoch:  41
# Epoch: 41, Test Loss(3.074296)
# Epoch:  42
# Epoch: 42, Test Loss(2.955152)
# Epoch:  43
# Epoch: 43, Test Loss(2.906636)
# Epoch:  44
# Epoch: 44, Test Loss(2.821148)
# Epoch:  45
# Epoch: 45, Test Loss(2.663076)
# Epoch:  46
# Epoch: 46, Test Loss(4.716100)
# Epoch:  47
# Epoch: 47, Test Loss(1.121720)
# Epoch:  48
# Epoch: 48, Test Loss(0.967868)
# Epoch:  49
# Epoch: 49, Test Loss(2.911778)
# Epoch:  50
# Epoch: 50, Test Loss(2.953344)
# Epoch:  51
# Epoch: 51, Test Loss(2.866724)
# Epoch:  52
# Epoch: 52, Test Loss(2.680229)
# Epoch:  53
# Epoch: 53, Test Loss(1.142380)
# Epoch:  54
# Epoch: 54, Test Loss(0.738131)
# Epoch:  55
# Epoch: 55, Test Loss(4.125891)
# Epoch:  56
# Epoch: 56, Test Loss(1.026238)
# Epoch:  57
# Epoch: 57, Test Loss(0.754167)
# Epoch:  58
# Epoch: 58, Test Loss(0.842182)
# Epoch:  59
# Epoch: 59, Train Loss Decreased!! (4.559855-->4.487398)
# Epoch: 59, Test Loss(0.719137)
# Epoch:  60
# Epoch: 60, Train Loss Decreased!! (4.487398-->4.345833)
# Epoch: 60, Test Loss(0.755893)
# Epoch:  61
# Epoch: 61, Test Loss(0.701094)
# Epoch:  62
# Epoch: 62, Train Loss Decreased!! (4.345833-->4.022453)
# Epoch: 62, Test Loss(0.525061)
# Epoch:  63
# Epoch: 63, Test Loss(0.966555)
# Epoch:  64
# Epoch: 64, Test Loss(1.028644)
# Epoch:  65
# Epoch: 65, Test Loss(0.732467)
# Epoch:  66
# Epoch: 66, Test Loss(0.848723)
# Epoch:  67
# Epoch: 67, Test Loss(1.480970)
# Epoch:  68
# Epoch: 68, Test Loss(0.989340)
# Epoch:  69
# Epoch: 69, Test Loss(1.371768)
# Epoch:  70
# Epoch: 70, Test Loss(0.593538)
# Epoch:  71
# Epoch: 71, Train Loss Decreased!! (4.022453-->3.916672)
# Epoch: 71, Test Loss(0.733968)
# Epoch:  72
# Epoch: 72, Train Loss Decreased!! (3.916672-->3.292781)
# Epoch: 72, Test Loss(0.234031)
# Epoch:  73
# Epoch: 73, Train Loss Decreased!! (3.292781-->1.055671)
# Epoch: 73, Test Loss(0.221081)
# Epoch:  74
# Epoch: 74, Train Loss Decreased!! (1.055671-->0.883843)
# Epoch: 74, Test Loss(0.087984)
# Epoch:  75
# Epoch: 75, Train Loss Decreased!! (0.883843-->0.362277)
# Epoch: 75, Test Loss(0.052090)
# Epoch:  76
# Epoch: 76, Test Loss(0.118471)
# Epoch:  77
# Epoch: 77, Test Loss(0.053972)
# Epoch:  78
# Epoch: 78, Train Loss Decreased!! (0.362277-->0.240139)
# Epoch: 78, Test Loss(0.040667)
# Epoch:  79
# Epoch: 79, Train Loss Decreased!! (0.240139-->0.185648)
# Epoch: 79, Test Loss(0.028534)
# Epoch:  80
# Epoch: 80, Test Loss(0.154258)
# Epoch:  81
# Epoch: 81, Test Loss(0.820854)
# Epoch:  82
# Epoch: 82, Test Loss(0.117572)
# Epoch:  83
# Epoch: 83, Test Loss(0.066756)
# Epoch:  84
# Epoch: 84, Test Loss(0.052194)
# Epoch:  85
# Epoch: 85, Test Loss(0.044583)
# Epoch:  86
# Epoch: 86, Test Loss(0.036328)
# Epoch:  87
# Epoch: 87, Train Loss Decreased!! (0.185648-->0.166773)
# Epoch: 87, Test Loss(0.031362)
# Epoch:  88
# Epoch: 88, Train Loss Decreased!! (0.166773-->0.140158)
# Epoch: 88, Test Loss(0.023749)
# Epoch:  89
# Epoch: 89, Train Loss Decreased!! (0.140158-->0.119821)
# Epoch: 89, Test Loss(0.019552)
# Epoch:  90
# Epoch: 90, Train Loss Decreased!! (0.119821-->0.107736)
# Epoch: 90, Test Loss(0.017951)
# Epoch:  91
# Epoch: 91, Train Loss Decreased!! (0.107736-->0.099821)
# Epoch: 91, Test Loss(0.016684)
# Epoch:  92
# Epoch: 92, Train Loss Decreased!! (0.099821-->0.093383)
# Epoch: 92, Test Loss(0.015620)
# Epoch:  93
# Epoch: 93, Train Loss Decreased!! (0.093383-->0.087864)
# Epoch: 93, Test Loss(0.014705)
# Epoch:  94
# Epoch: 94, Train Loss Decreased!! (0.087864-->0.083088)
# Epoch: 94, Test Loss(0.013913)
# Epoch:  95
# Epoch: 95, Train Loss Decreased!! (0.083088-->0.078879)
# Epoch: 95, Test Loss(0.013220)
# Epoch:  96
# Epoch: 96, Train Loss Decreased!! (0.078879-->0.075144)
# Epoch: 96, Test Loss(0.012596)
# Epoch:  97
# Epoch: 97, Train Loss Decreased!! (0.075144-->0.071738)
# Epoch: 97, Test Loss(0.012024)
# Epoch:  98
# Epoch: 98, Train Loss Decreased!! (0.071738-->0.068635)
# Epoch: 98, Test Loss(0.011504)
# Epoch:  99
# Epoch: 99, Train Loss Decreased!! (0.068635-->0.065780)
# Epoch: 99, Test Loss(0.011035)
# Epoch:  100
#  20%|██        | 1/5 [04:46<19:07, 286.75s/it]
# Epoch: 100, Train Loss Decreased!! (0.065780-->0.063154)
# Epoch: 100, Test Loss(0.010593)
# Epoch:  1
# Epoch: 1, Train Loss Decreased!! (inf-->19.809623)
# Epoch: 1, Test Loss(3.197590)
# Epoch:  2
# Epoch: 2, Train Loss Decreased!! (19.809623-->19.478900)
# Epoch: 2, Test Loss(3.305432)
# Epoch:  3
# Epoch: 3, Train Loss Decreased!! (19.478900-->19.390260)
# Epoch: 3, Test Loss(3.285234)
# Epoch:  4
# Epoch: 4, Test Loss(3.218145)
# Epoch:  5
# Epoch: 5, Train Loss Decreased!! (19.390260-->19.364277)
# Epoch: 5, Test Loss(3.171929)
# Epoch:  6
# Epoch: 6, Test Loss(3.973868)
# Epoch:  7
# Epoch: 7, Train Loss Decreased!! (19.364277-->19.162916)
# Epoch: 7, Test Loss(3.054482)
# Epoch:  8
# Epoch: 8, Train Loss Decreased!! (19.162916-->18.164882)
# Epoch: 8, Test Loss(2.978813)
# Epoch:  9
# Epoch: 9, Train Loss Decreased!! (18.164882-->17.796949)
# Epoch: 9, Test Loss(2.923803)
# Epoch:  10
# Epoch: 10, Train Loss Decreased!! (17.796949-->17.388502)
# Epoch: 10, Test Loss(2.822074)
# Epoch:  11
# Epoch: 11, Train Loss Decreased!! (17.388502-->13.494182)
# Epoch: 11, Test Loss(1.149024)
# Epoch:  12
# Epoch: 12, Train Loss Decreased!! (13.494182-->5.878553)
# Epoch: 12, Test Loss(0.555857)
# Epoch:  13
# Epoch: 13, Train Loss Decreased!! (5.878553-->2.623066)
# Epoch: 13, Test Loss(0.363188)
# Epoch:  14
# Epoch: 14, Train Loss Decreased!! (2.623066-->1.881724)
# Epoch: 14, Test Loss(0.254546)
# Epoch:  15
# Epoch: 15, Train Loss Decreased!! (1.881724-->1.327983)
# Epoch: 15, Test Loss(0.303109)
# Epoch:  16
# Epoch: 16, Test Loss(0.256405)
# Epoch:  17
# Epoch: 17, Train Loss Decreased!! (1.327983-->0.940909)
# Epoch: 17, Test Loss(0.175921)
# Epoch:  18
# Epoch: 18, Train Loss Decreased!! (0.940909-->0.801972)
# Epoch: 18, Test Loss(0.155439)
# Epoch:  19
# Epoch: 19, Train Loss Decreased!! (0.801972-->0.762192)
# Epoch: 19, Test Loss(0.147994)
# Epoch:  20
# Epoch: 20, Train Loss Decreased!! (0.762192-->0.738029)
# Epoch: 20, Test Loss(0.136260)
# Epoch:  21
# Epoch: 21, Test Loss(0.134484)
# Epoch:  22
# Epoch: 22, Train Loss Decreased!! (0.738029-->0.561986)
# Epoch: 22, Test Loss(0.102769)
# Epoch:  23
# Epoch: 23, Train Loss Decreased!! (0.561986-->0.429539)
# Epoch: 23, Test Loss(0.098105)
# Epoch:  24
# Epoch: 24, Train Loss Decreased!! (0.429539-->0.390408)
# Epoch: 24, Test Loss(0.078130)
# Epoch:  25
# Epoch: 25, Test Loss(0.078584)
# Epoch:  26
# Epoch: 26, Train Loss Decreased!! (0.390408-->0.366608)
# Epoch: 26, Test Loss(0.078023)
# Epoch:  27
# Epoch: 27, Train Loss Decreased!! (0.366608-->0.309081)
# Epoch: 27, Test Loss(0.061055)
# Epoch:  28
# Epoch: 28, Train Loss Decreased!! (0.309081-->0.279784)
# Epoch: 28, Test Loss(0.048528)
# Epoch:  29
# Epoch: 29, Train Loss Decreased!! (0.279784-->0.237863)
# Epoch: 29, Test Loss(0.038203)
# Epoch:  30
# Epoch: 30, Train Loss Decreased!! (0.237863-->0.205306)
# Epoch: 30, Test Loss(0.037107)
# Epoch:  31
# Epoch: 31, Train Loss Decreased!! (0.205306-->0.199188)
# Epoch: 31, Test Loss(0.031299)
# Epoch:  32
# Epoch: 32, Train Loss Decreased!! (0.199188-->0.179851)
# Epoch: 32, Test Loss(0.030070)
# Epoch:  33
# Epoch: 33, Train Loss Decreased!! (0.179851-->0.159631)
# Epoch: 33, Test Loss(0.028082)
# Epoch:  34
# Epoch: 34, Train Loss Decreased!! (0.159631-->0.149772)
# Epoch: 34, Test Loss(0.027070)
# Epoch:  35
# Epoch: 35, Train Loss Decreased!! (0.149772-->0.146428)
# Epoch: 35, Test Loss(0.024645)
# Epoch:  36
# Epoch: 36, Train Loss Decreased!! (0.146428-->0.135784)
# Epoch: 36, Test Loss(0.024124)
# Epoch:  37
# Epoch: 37, Train Loss Decreased!! (0.135784-->0.129291)
# Epoch: 37, Test Loss(0.023063)
# Epoch:  38
# Epoch: 38, Train Loss Decreased!! (0.129291-->0.123842)
# Epoch: 38, Test Loss(0.022135)
# Epoch:  39
# Epoch: 39, Train Loss Decreased!! (0.123842-->0.119848)
# Epoch: 39, Test Loss(0.021330)
# Epoch:  40
# Epoch: 40, Train Loss Decreased!! (0.119848-->0.116069)
# Epoch: 40, Test Loss(0.020651)
# Epoch:  41
# Epoch: 41, Train Loss Decreased!! (0.116069-->0.111477)
# Epoch: 41, Test Loss(0.019639)
# Epoch:  42
# Epoch: 42, Train Loss Decreased!! (0.111477-->0.107182)
# Epoch: 42, Test Loss(0.018835)
# Epoch:  43
# Epoch: 43, Train Loss Decreased!! (0.107182-->0.103528)
# Epoch: 43, Test Loss(0.018139)
# Epoch:  44
# Epoch: 44, Train Loss Decreased!! (0.103528-->0.098925)
# Epoch: 44, Test Loss(0.017054)
# Epoch:  45
# Epoch: 45, Train Loss Decreased!! (0.098925-->0.093673)
# Epoch: 45, Test Loss(0.016082)
# Epoch:  46
# Epoch: 46, Train Loss Decreased!! (0.093673-->0.089297)
# Epoch: 46, Test Loss(0.017727)
# Epoch:  47
# Epoch: 47, Train Loss Decreased!! (0.089297-->0.085128)
# Epoch: 47, Test Loss(0.013983)
# Epoch:  48
# Epoch: 48, Train Loss Decreased!! (0.085128-->0.076593)
# Epoch: 48, Test Loss(0.012632)
# Epoch:  49
# Epoch: 49, Train Loss Decreased!! (0.076593-->0.070252)
# Epoch: 49, Test Loss(0.021109)
# Epoch:  50
# Epoch: 50, Test Loss(0.010837)
# Epoch:  51
# Epoch: 51, Train Loss Decreased!! (0.070252-->0.058107)
# Epoch: 51, Test Loss(0.009459)
# Epoch:  52
# Epoch: 52, Train Loss Decreased!! (0.058107-->0.051769)
# Epoch: 52, Test Loss(0.009436)
# Epoch:  53
# Epoch: 53, Test Loss(0.009105)
# Epoch:  54
# Epoch: 54, Train Loss Decreased!! (0.051769-->0.047935)
# Epoch: 54, Test Loss(0.007814)
# Epoch:  55
# Epoch: 55, Train Loss Decreased!! (0.047935-->0.041894)
# Epoch: 55, Test Loss(0.006844)
# Epoch:  56
# Epoch: 56, Test Loss(0.012503)
# Epoch:  57
# Epoch: 57, Test Loss(0.006877)
# Epoch:  58
# Epoch: 58, Train Loss Decreased!! (0.041894-->0.036722)
# Epoch: 58, Test Loss(0.005892)
# Epoch:  59
# Epoch: 59, Train Loss Decreased!! (0.036722-->0.032094)
# Epoch: 59, Test Loss(0.005246)
# Epoch:  60
# Epoch: 60, Test Loss(0.005956)
# Epoch:  61
# Epoch: 61, Test Loss(0.004716)
# Epoch:  62
# Epoch: 62, Train Loss Decreased!! (0.032094-->0.026170)
# Epoch: 62, Test Loss(0.004278)
# Epoch:  63
# Epoch: 63, Train Loss Decreased!! (0.026170-->0.023772)
# Epoch: 63, Test Loss(0.003880)
# Epoch:  64
# Epoch: 64, Train Loss Decreased!! (0.023772-->0.021829)
# Epoch: 64, Test Loss(0.003715)
# Epoch:  65
# Epoch: 65, Train Loss Decreased!! (0.021829-->0.020791)
# Epoch: 65, Test Loss(0.003450)
# Epoch:  66
# Epoch: 66, Train Loss Decreased!! (0.020791-->0.020054)
# Epoch: 66, Test Loss(0.006629)
# Epoch:  67
# Epoch: 67, Test Loss(0.003163)
# Epoch:  68
# Epoch: 68, Train Loss Decreased!! (0.020054-->0.017583)
# Epoch: 68, Test Loss(0.002873)
# Epoch:  69
# Epoch: 69, Train Loss Decreased!! (0.017583-->0.016397)
# Epoch: 69, Test Loss(0.002691)
# Epoch:  70
# Epoch: 70, Train Loss Decreased!! (0.016397-->0.015506)
# Epoch: 70, Test Loss(0.002725)
# Epoch:  71
# Epoch: 71, Test Loss(0.002608)
# Epoch:  72
# Epoch: 72, Train Loss Decreased!! (0.015506-->0.014841)
# Epoch: 72, Test Loss(0.002389)
# Epoch:  73
# Epoch: 73, Train Loss Decreased!! (0.014841-->0.013708)
# Epoch: 73, Test Loss(0.002238)
# Epoch:  74
# Epoch: 74, Train Loss Decreased!! (0.013708-->0.012916)
# Epoch: 74, Test Loss(0.002113)
# Epoch:  75
# Epoch: 75, Train Loss Decreased!! (0.012916-->0.012828)
# Epoch: 75, Test Loss(0.002548)
# Epoch:  76
# Epoch: 76, Train Loss Decreased!! (0.012828-->0.012077)
# Epoch: 76, Test Loss(0.001924)
# Epoch:  77
# Epoch: 77, Train Loss Decreased!! (0.012077-->0.011176)
# Epoch: 77, Test Loss(0.001832)
# Epoch:  78
# Epoch: 78, Test Loss(0.004274)
# Epoch:  79
# Epoch: 79, Test Loss(0.002236)
# Epoch:  80
# Epoch: 80, Test Loss(0.001935)
# Epoch:  81
# Epoch: 81, Test Loss(0.001780)
# Epoch:  82
# Epoch: 82, Train Loss Decreased!! (0.011176-->0.010310)
# Epoch: 82, Test Loss(0.001652)
# Epoch:  83
# Epoch: 83, Train Loss Decreased!! (0.010310-->0.009649)
# Epoch: 83, Test Loss(0.001546)
# Epoch:  84
# Epoch: 84, Train Loss Decreased!! (0.009649-->0.009051)
# Epoch: 84, Test Loss(0.001462)
# Epoch:  85
# Epoch: 85, Train Loss Decreased!! (0.009051-->0.008571)
# Epoch: 85, Test Loss(0.001382)
# Epoch:  86
# Epoch: 86, Train Loss Decreased!! (0.008571-->0.008115)
# Epoch: 86, Test Loss(0.001313)
# Epoch:  87
# Epoch: 87, Train Loss Decreased!! (0.008115-->0.007725)
# Epoch: 87, Test Loss(0.001251)
# Epoch:  88
# Epoch: 88, Train Loss Decreased!! (0.007725-->0.007363)
# Epoch: 88, Test Loss(0.001196)
# Epoch:  89
# Epoch: 89, Train Loss Decreased!! (0.007363-->0.007040)
# Epoch: 89, Test Loss(0.001144)
# Epoch:  90
# Epoch: 90, Train Loss Decreased!! (0.007040-->0.006746)
# Epoch: 90, Test Loss(0.001095)
# Epoch:  91
# Epoch: 91, Train Loss Decreased!! (0.006746-->0.006465)
# Epoch: 91, Test Loss(0.001051)
# Epoch:  92
# Epoch: 92, Train Loss Decreased!! (0.006465-->0.006216)
# Epoch: 92, Test Loss(0.001011)
# Epoch:  93
# Epoch: 93, Train Loss Decreased!! (0.006216-->0.005976)
# Epoch: 93, Test Loss(0.000971)
# Epoch:  94
# Epoch: 94, Test Loss(0.003661)
# Epoch:  95
# Epoch: 95, Test Loss(0.000998)
# Epoch:  96
# Epoch: 96, Test Loss(0.000936)
# Epoch:  97
# Epoch: 97, Train Loss Decreased!! (0.005976-->0.005483)
# Epoch: 97, Test Loss(0.000888)
# Epoch:  98
# Epoch: 98, Train Loss Decreased!! (0.005483-->0.005241)
# Epoch: 98, Test Loss(0.000847)
# Epoch:  99
# Epoch: 99, Train Loss Decreased!! (0.005241-->0.005028)
# Epoch: 99, Test Loss(0.000815)
# Epoch:  100
# Epoch: 100, Train Loss Decreased!! (0.005028-->0.004837)
#  40%|████      | 2/5 [09:32<14:18, 286.11s/it]
# Epoch: 100, Test Loss(0.000783)
# Epoch:  1
# Epoch: 1, Train Loss Decreased!! (inf-->19.616411)
# Epoch: 1, Test Loss(3.219396)
# Epoch:  2
# Epoch: 2, Train Loss Decreased!! (19.616411-->19.360186)
# Epoch: 2, Test Loss(3.200395)
# Epoch:  3
# Epoch: 3, Train Loss Decreased!! (19.360186-->19.334360)
# Epoch: 3, Test Loss(3.192901)
# Epoch:  4
# Epoch: 4, Test Loss(3.195582)
# Epoch:  5
# Epoch: 5, Train Loss Decreased!! (19.334360-->18.973334)
# Epoch: 5, Test Loss(3.005587)
# Epoch:  6
# Epoch: 6, Train Loss Decreased!! (18.973334-->18.679808)
# Epoch: 6, Test Loss(2.924446)
# Epoch:  7
# Epoch: 7, Train Loss Decreased!! (18.679808-->18.129066)
# Epoch: 7, Test Loss(3.176460)
# Epoch:  8
# Epoch: 8, Test Loss(2.939589)
# Epoch:  9
# Epoch: 9, Train Loss Decreased!! (18.129066-->16.700526)
# Epoch: 9, Test Loss(2.378871)
# Epoch:  10
# Epoch: 10, Train Loss Decreased!! (16.700526-->12.484406)
# Epoch: 10, Test Loss(1.424902)
# Epoch:  11
# Epoch: 11, Test Loss(3.201815)
# Epoch:  12
# Epoch: 12, Test Loss(2.478725)
# Epoch:  13
# Epoch: 13, Train Loss Decreased!! (12.484406-->11.975337)
# Epoch: 13, Test Loss(3.548201)
# Epoch:  14
# Epoch: 14, Test Loss(2.459164)
# Epoch:  15
# Epoch: 15, Train Loss Decreased!! (11.975337-->11.853182)
# Epoch: 15, Test Loss(1.035664)
# Epoch:  16
# Epoch: 16, Train Loss Decreased!! (11.853182-->10.504953)
# Epoch: 16, Test Loss(0.689994)
# Epoch:  17
# Epoch: 17, Train Loss Decreased!! (10.504953-->7.135430)
# Epoch: 17, Test Loss(0.609613)
# Epoch:  18
# Epoch: 18, Test Loss(1.624429)
# Epoch:  19
# Epoch: 19, Train Loss Decreased!! (7.135430-->6.651295)
# Epoch: 19, Test Loss(0.526802)
# Epoch:  20
# Epoch: 20, Train Loss Decreased!! (6.651295-->5.028686)
# Epoch: 20, Test Loss(0.934081)
# Epoch:  21
# Epoch: 21, Train Loss Decreased!! (5.028686-->4.967873)
# Epoch: 21, Test Loss(0.348348)
# Epoch:  22
# Epoch: 22, Train Loss Decreased!! (4.967873-->4.111745)
# Epoch: 22, Test Loss(0.462659)
# Epoch:  23
# Epoch: 23, Test Loss(0.700632)
# Epoch:  24
# Epoch: 24, Train Loss Decreased!! (4.111745-->3.795089)
# Epoch: 24, Test Loss(1.061499)
# Epoch:  25
# Epoch: 25, Test Loss(0.739504)
# Epoch:  26
# Epoch: 26, Train Loss Decreased!! (3.795089-->3.702654)
# Epoch: 26, Test Loss(0.586582)
# Epoch:  27
# Epoch: 27, Test Loss(0.604945)
# Epoch:  28
# Epoch: 28, Test Loss(5.070661)
# Epoch:  29
# Epoch: 29, Test Loss(1.702693)
# Epoch:  30
# Epoch: 30, Test Loss(0.777547)
# Epoch:  31
# Epoch: 31, Test Loss(0.746805)
# Epoch:  32
# Epoch: 32, Test Loss(0.602184)
# Epoch:  33
# Epoch: 33, Test Loss(1.004113)
# Epoch:  34
# Epoch: 34, Test Loss(0.530825)
# Epoch:  35
# Epoch: 35, Test Loss(0.878404)
# Epoch:  36
# Epoch: 36, Test Loss(0.417281)
# Epoch:  37
# Epoch: 37, Test Loss(1.292384)
# Epoch:  38
# Epoch: 38, Test Loss(0.939624)
# Epoch:  39
# Epoch: 39, Test Loss(3.233400)
# Epoch:  40
# Epoch: 40, Test Loss(3.012658)
# Epoch:  41
# Epoch: 41, Test Loss(2.980720)
# Epoch:  42
# Epoch: 42, Test Loss(2.917975)
# Epoch:  43
# Epoch: 43, Test Loss(2.799993)
# Epoch:  44
# Epoch: 44, Test Loss(2.429649)
# Epoch:  45
# Epoch: 45, Test Loss(3.101898)
# Epoch:  46
# Epoch: 46, Test Loss(2.944922)
# Epoch:  47
# Epoch: 47, Test Loss(2.884651)
# Epoch:  48
# Epoch: 48, Test Loss(2.816931)
# Epoch:  49
# Epoch: 49, Test Loss(2.730280)
# Epoch:  50
# Epoch: 50, Test Loss(2.538176)
# Epoch:  51
# Epoch: 51, Test Loss(2.996930)
# Epoch:  52
# Epoch: 52, Test Loss(2.755782)
# Epoch:  53
# Epoch: 53, Test Loss(0.864341)
# Epoch:  54
# Epoch: 54, Test Loss(6.806258)
# Epoch:  55
# Epoch: 55, Test Loss(3.083148)
# Epoch:  56
# Epoch: 56, Test Loss(3.052192)
# Epoch:  57
# Epoch: 57, Test Loss(2.980580)
# Epoch:  58
# Epoch: 58, Test Loss(2.816192)
# Epoch:  59
# Epoch: 59, Test Loss(2.072602)
# Epoch:  60
# Epoch: 60, Test Loss(2.469715)
# Epoch:  61
# Epoch: 61, Test Loss(1.389844)
# Epoch:  62
# Epoch: 62, Test Loss(3.209941)
# Epoch:  63
# Epoch: 63, Test Loss(2.490986)
# Epoch:  64
# Epoch: 64, Test Loss(1.914868)
# Epoch:  65
# Epoch: 65, Test Loss(0.767838)
# Epoch:  66
# Epoch: 66, Test Loss(0.562533)
# Epoch:  67
# Epoch: 67, Test Loss(0.635033)
# Epoch:  68
# Epoch: 68, Test Loss(7.546566)
# Epoch:  69
# Epoch: 69, Test Loss(4.749957)
# Epoch:  70
# Epoch: 70, Test Loss(0.866766)
# Epoch:  71
# Epoch: 71, Test Loss(1.667532)
# Epoch:  72
# Epoch: 72, Test Loss(1.250809)
# Epoch:  73
# Epoch: 73, Test Loss(1.034186)
# Epoch:  74
# Epoch: 74, Test Loss(1.023495)
# Epoch:  75
# Epoch: 75, Test Loss(0.946118)
# Epoch:  76
# Epoch: 76, Test Loss(0.852716)
# Epoch:  77
# Epoch: 77, Test Loss(0.760153)
# Epoch:  78
# Epoch: 78, Test Loss(0.762918)
# Epoch:  79
# Epoch: 79, Test Loss(1.044924)
# Epoch:  80
# Epoch: 80, Test Loss(0.445825)
# Epoch:  81
# Epoch: 81, Train Loss Decreased!! (3.702654-->2.167281)
# Epoch: 81, Test Loss(0.252371)
# Epoch:  82
# Epoch: 82, Train Loss Decreased!! (2.167281-->1.283474)
# Epoch: 82, Test Loss(0.172212)
# Epoch:  83
# Epoch: 83, Test Loss(0.186425)
# Epoch:  84
# Epoch: 84, Train Loss Decreased!! (1.283474-->0.975306)
# Epoch: 84, Test Loss(0.111067)
# Epoch:  85
# Epoch: 85, Train Loss Decreased!! (0.975306-->0.616159)
# Epoch: 85, Test Loss(0.081621)
# Epoch:  86
# Epoch: 86, Train Loss Decreased!! (0.616159-->0.485743)
# Epoch: 86, Test Loss(0.069315)
# Epoch:  87
# Epoch: 87, Train Loss Decreased!! (0.485743-->0.406397)
# Epoch: 87, Test Loss(0.058990)
# Epoch:  88
# Epoch: 88, Train Loss Decreased!! (0.406397-->0.350617)
# Epoch: 88, Test Loss(0.052207)
# Epoch:  89
# Epoch: 89, Train Loss Decreased!! (0.350617-->0.317826)
# Epoch: 89, Test Loss(0.048773)
# Epoch:  90
# Epoch: 90, Train Loss Decreased!! (0.317826-->0.288481)
# Epoch: 90, Test Loss(0.042082)
# Epoch:  91
# Epoch: 91, Train Loss Decreased!! (0.288481-->0.262004)
# Epoch: 91, Test Loss(0.038745)
# Epoch:  92
# Epoch: 92, Test Loss(0.071267)
# Epoch:  93
# Epoch: 93, Test Loss(0.039252)
# Epoch:  94
# Epoch: 94, Train Loss Decreased!! (0.262004-->0.225251)
# Epoch: 94, Test Loss(0.033818)
# Epoch:  95
# Epoch: 95, Train Loss Decreased!! (0.225251-->0.200750)
# Epoch: 95, Test Loss(0.031476)
# Epoch:  96
# Epoch: 96, Train Loss Decreased!! (0.200750-->0.183097)
# Epoch: 96, Test Loss(0.028568)
# Epoch:  97
# Epoch: 97, Train Loss Decreased!! (0.183097-->0.171962)
# Epoch: 97, Test Loss(0.025925)
# Epoch:  98
# Epoch: 98, Train Loss Decreased!! (0.171962-->0.159110)
# Epoch: 98, Test Loss(0.024270)
# Epoch:  99
# Epoch: 99, Train Loss Decreased!! (0.159110-->0.145811)
# Epoch: 99, Test Loss(0.022774)
# Epoch:  100
#  60%|██████    | 3/5 [14:18<09:32, 286.22s/it]
# Epoch: 100, Train Loss Decreased!! (0.145811-->0.136894)
# Epoch: 100, Test Loss(0.021691)
# Epoch:  1
# Epoch: 1, Train Loss Decreased!! (inf-->20.263983)
# Epoch: 1, Test Loss(3.195038)
# Epoch:  2
# Epoch: 2, Train Loss Decreased!! (20.263983-->19.464389)
# Epoch: 2, Test Loss(3.182260)
# Epoch:  3
# Epoch: 3, Train Loss Decreased!! (19.464389-->19.437831)
# Epoch: 3, Test Loss(3.183223)
# Epoch:  4
# Epoch: 4, Train Loss Decreased!! (19.437831-->19.375426)
# Epoch: 4, Test Loss(3.149547)
# Epoch:  5
# Epoch: 5, Train Loss Decreased!! (19.375426-->19.249905)
# Epoch: 5, Test Loss(3.147887)
# Epoch:  6
# Epoch: 6, Test Loss(3.253755)
# Epoch:  7
# Epoch: 7, Train Loss Decreased!! (19.249905-->19.165921)
# Epoch: 7, Test Loss(3.110366)
# Epoch:  8
# Epoch: 8, Train Loss Decreased!! (19.165921-->18.909069)
# Epoch: 8, Test Loss(3.058371)
# Epoch:  9
# Epoch: 9, Train Loss Decreased!! (18.909069-->18.245442)
# Epoch: 9, Test Loss(2.765498)
# Epoch:  10
# Epoch: 10, Test Loss(3.123555)
# Epoch:  11
# Epoch: 11, Test Loss(3.098739)
# Epoch:  12
# Epoch: 12, Test Loss(3.038401)
# Epoch:  13
# Epoch: 13, Test Loss(2.954352)
# Epoch:  14
# Epoch: 14, Train Loss Decreased!! (18.245442-->17.521764)
# Epoch: 14, Test Loss(2.900200)
# Epoch:  15
# Epoch: 15, Test Loss(2.890396)
# Epoch:  16
# Epoch: 16, Train Loss Decreased!! (17.521764-->17.107476)
# Epoch: 16, Test Loss(2.593796)
# Epoch:  17
# Epoch: 17, Train Loss Decreased!! (17.107476-->16.418468)
# Epoch: 17, Test Loss(2.346352)
# Epoch:  18
# Epoch: 18, Train Loss Decreased!! (16.418468-->14.389080)
# Epoch: 18, Test Loss(2.261252)
# Epoch:  19
# Epoch: 19, Test Loss(3.105275)
# Epoch:  20
# Epoch: 20, Test Loss(2.362946)
# Epoch:  21
# Epoch: 21, Test Loss(4.467222)
# Epoch:  22
# Epoch: 22, Test Loss(2.571035)
# Epoch:  23
# Epoch: 23, Test Loss(5.380330)
# Epoch:  24
# Epoch: 24, Test Loss(2.526914)
# Epoch:  25
# Epoch: 25, Train Loss Decreased!! (14.389080-->10.497209)
# Epoch: 25, Test Loss(0.867823)
# Epoch:  26
# Epoch: 26, Test Loss(2.164995)
# Epoch:  27
# Epoch: 27, Train Loss Decreased!! (10.497209-->8.948997)
# Epoch: 27, Test Loss(0.668733)
# Epoch:  28
# Epoch: 28, Train Loss Decreased!! (8.948997-->8.768213)
# Epoch: 28, Test Loss(1.805355)
# Epoch:  29
# Epoch: 29, Train Loss Decreased!! (8.768213-->6.006775)
# Epoch: 29, Test Loss(0.788988)
# Epoch:  30
# Epoch: 30, Train Loss Decreased!! (6.006775-->4.688049)
# Epoch: 30, Test Loss(2.340636)
# Epoch:  31
# Epoch: 31, Test Loss(0.914720)
# Epoch:  32
# Epoch: 32, Test Loss(0.753431)
# Epoch:  33
# Epoch: 33, Train Loss Decreased!! (4.688049-->4.005968)
# Epoch: 33, Test Loss(2.089980)
# Epoch:  34
# Epoch: 34, Test Loss(0.929085)
# Epoch:  35
# Epoch: 35, Test Loss(3.865571)
# Epoch:  36
# Epoch: 36, Test Loss(1.399854)
# Epoch:  37
# Epoch: 37, Test Loss(1.627236)
# Epoch:  38
# Epoch: 38, Test Loss(1.113438)
# Epoch:  39
# Epoch: 39, Test Loss(0.897563)
# Epoch:  40
# Epoch: 40, Test Loss(1.736265)
# Epoch:  41
# Epoch: 41, Test Loss(0.909614)
# Epoch:  42
# Epoch: 42, Test Loss(0.892345)
# Epoch:  43
# Epoch: 43, Test Loss(0.877416)
# Epoch:  44
# Epoch: 44, Test Loss(6.393066)
# Epoch:  45
# Epoch: 45, Test Loss(3.187379)
# Epoch:  46
# Epoch: 46, Test Loss(3.055666)
# Epoch:  47
# Epoch: 47, Test Loss(3.014801)
# Epoch:  48
# Epoch: 48, Test Loss(2.977597)
# Epoch:  49
# Epoch: 49, Test Loss(2.909142)
# Epoch:  50
# Epoch: 50, Test Loss(2.808661)
# Epoch:  51
# Epoch: 51, Test Loss(2.314724)
# Epoch:  52
# Epoch: 52, Test Loss(1.234039)
# Epoch:  53
# Epoch: 53, Test Loss(1.124735)
# Epoch:  54
# Epoch: 54, Test Loss(0.824480)
# Epoch:  55
# Epoch: 55, Test Loss(4.278321)
# Epoch:  56
# Epoch: 56, Test Loss(1.796494)
# Epoch:  57
# Epoch: 57, Test Loss(0.897396)
# Epoch:  58
# Epoch: 58, Test Loss(0.535615)
# Epoch:  59
# Epoch: 59, Train Loss Decreased!! (4.005968-->2.985876)
# Epoch: 59, Test Loss(0.346811)
# Epoch:  60
# Epoch: 60, Train Loss Decreased!! (2.985876-->2.018007)
# Epoch: 60, Test Loss(0.263330)
# Epoch:  61
# Epoch: 61, Train Loss Decreased!! (2.018007-->1.576045)
# Epoch: 61, Test Loss(0.221150)
# Epoch:  62
# Epoch: 62, Train Loss Decreased!! (1.576045-->1.351724)
# Epoch: 62, Test Loss(0.209974)
# Epoch:  63
# Epoch: 63, Train Loss Decreased!! (1.351724-->1.140195)
# Epoch: 63, Test Loss(0.153137)
# Epoch:  64
# Epoch: 64, Train Loss Decreased!! (1.140195-->1.048729)
# Epoch: 64, Test Loss(0.179105)
# Epoch:  65
# Epoch: 65, Train Loss Decreased!! (1.048729-->0.880678)
# Epoch: 65, Test Loss(0.132036)
# Epoch:  66
# Epoch: 66, Train Loss Decreased!! (0.880678-->0.797193)
# Epoch: 66, Test Loss(0.118261)
# Epoch:  67
# Epoch: 67, Train Loss Decreased!! (0.797193-->0.658212)
# Epoch: 67, Test Loss(0.102971)
# Epoch:  68
# Epoch: 68, Train Loss Decreased!! (0.658212-->0.583405)
# Epoch: 68, Test Loss(0.093931)
# Epoch:  69
# Epoch: 69, Test Loss(0.094237)
# Epoch:  70
# Epoch: 70, Train Loss Decreased!! (0.583405-->0.523485)
# Epoch: 70, Test Loss(0.073741)
# Epoch:  71
# Epoch: 71, Test Loss(0.154258)
# Epoch:  72
# Epoch: 72, Test Loss(0.080630)
# Epoch:  73
# Epoch: 73, Train Loss Decreased!! (0.523485-->0.466180)
# Epoch: 73, Test Loss(0.066628)
# Epoch:  74
# Epoch: 74, Train Loss Decreased!! (0.466180-->0.384769)
# Epoch: 74, Test Loss(0.059301)
# Epoch:  75
# Epoch: 75, Train Loss Decreased!! (0.384769-->0.367254)
# Epoch: 75, Test Loss(0.057499)
# Epoch:  76
# Epoch: 76, Train Loss Decreased!! (0.367254-->0.331357)
# Epoch: 76, Test Loss(0.055036)
# Epoch:  77
# Epoch: 77, Train Loss Decreased!! (0.331357-->0.291780)
# Epoch: 77, Test Loss(0.050515)
# Epoch:  78
# Epoch: 78, Test Loss(0.073271)
# Epoch:  79
# Epoch: 79, Test Loss(0.049823)
# Epoch:  80
# Epoch: 80, Train Loss Decreased!! (0.291780-->0.259498)
# Epoch: 80, Test Loss(0.040888)
# Epoch:  81
# Epoch: 81, Train Loss Decreased!! (0.259498-->0.233874)
# Epoch: 81, Test Loss(0.037224)
# Epoch:  82
# Epoch: 82, Train Loss Decreased!! (0.233874-->0.215313)
# Epoch: 82, Test Loss(0.034755)
# Epoch:  83
# Epoch: 83, Train Loss Decreased!! (0.215313-->0.203483)
# Epoch: 83, Test Loss(0.032976)
# Epoch:  84
# Epoch: 84, Train Loss Decreased!! (0.203483-->0.196768)
# Epoch: 84, Test Loss(0.033487)
# Epoch:  85
# Epoch: 85, Test Loss(0.040488)
# Epoch:  86
# Epoch: 86, Train Loss Decreased!! (0.196768-->0.188571)
# Epoch: 86, Test Loss(0.029611)
# Epoch:  87
# Epoch: 87, Train Loss Decreased!! (0.188571-->0.168371)
# Epoch: 87, Test Loss(0.031032)
# Epoch:  88
# Epoch: 88, Train Loss Decreased!! (0.168371-->0.159684)
# Epoch: 88, Test Loss(0.027235)
# Epoch:  89
# Epoch: 89, Train Loss Decreased!! (0.159684-->0.155104)
# Epoch: 89, Test Loss(0.024833)
# Epoch:  90
# Epoch: 90, Train Loss Decreased!! (0.155104-->0.142398)
# Epoch: 90, Test Loss(0.023495)
# Epoch:  91
# Epoch: 91, Test Loss(0.025803)
# Epoch:  92
# Epoch: 92, Test Loss(0.022803)
# Epoch:  93
# Epoch: 93, Train Loss Decreased!! (0.142398-->0.131666)
# Epoch: 93, Test Loss(0.022253)
# Epoch:  94
# Epoch: 94, Test Loss(0.025462)
# Epoch:  95
# Epoch: 95, Train Loss Decreased!! (0.131666-->0.127203)
# Epoch: 95, Test Loss(0.020235)
# Epoch:  96
# Epoch: 96, Train Loss Decreased!! (0.127203-->0.116912)
# Epoch: 96, Test Loss(0.021361)
# Epoch:  97
# Epoch: 97, Test Loss(0.018636)
# Epoch:  98
# Epoch: 98, Train Loss Decreased!! (0.116912-->0.105662)
# Epoch: 98, Test Loss(0.017533)
# Epoch:  99
# Epoch: 99, Test Loss(0.021769)
# Epoch:  100
#  80%|████████  | 4/5 [19:05<04:46, 286.54s/it]
# Epoch: 100, Test Loss(0.017240)
# Epoch:  1
# Epoch: 1, Train Loss Decreased!! (inf-->19.802998)
# Epoch: 1, Test Loss(3.177009)
# Epoch:  2
# Epoch: 2, Train Loss Decreased!! (19.802998-->19.569189)
# Epoch: 2, Test Loss(3.196526)
# Epoch:  3
# Epoch: 3, Test Loss(3.146097)
# Epoch:  4
# Epoch: 4, Train Loss Decreased!! (19.569189-->19.368491)
# Epoch: 4, Test Loss(3.080246)
# Epoch:  5
# Epoch: 5, Test Loss(3.193630)
# Epoch:  6
# Epoch: 6, Train Loss Decreased!! (19.368491-->19.222098)
# Epoch: 6, Test Loss(3.052937)
# Epoch:  7
# Epoch: 7, Train Loss Decreased!! (19.222098-->18.428862)
# Epoch: 7, Test Loss(2.835994)
# Epoch:  8
# Epoch: 8, Train Loss Decreased!! (18.428862-->17.824592)
# Epoch: 8, Test Loss(2.871941)
# Epoch:  9
# Epoch: 9, Test Loss(2.908087)
# Epoch:  10
# Epoch: 10, Train Loss Decreased!! (17.824592-->16.269197)
# Epoch: 10, Test Loss(1.912134)
# Epoch:  11
# Epoch: 11, Train Loss Decreased!! (16.269197-->14.188369)
# Epoch: 11, Test Loss(1.809120)
# Epoch:  12
# Epoch: 12, Test Loss(1.872347)
# Epoch:  13
# Epoch: 13, Test Loss(2.103711)
# Epoch:  14
# Epoch: 14, Train Loss Decreased!! (14.188369-->10.567934)
# Epoch: 14, Test Loss(2.465102)
# Epoch:  15
# Epoch: 15, Train Loss Decreased!! (10.567934-->9.743548)
# Epoch: 15, Test Loss(0.724260)
# Epoch:  16
# Epoch: 16, Train Loss Decreased!! (9.743548-->5.278316)
# Epoch: 16, Test Loss(0.652203)
# Epoch:  17
# Epoch: 17, Test Loss(1.742761)
# Epoch:  18
# Epoch: 18, Train Loss Decreased!! (5.278316-->4.166647)
# Epoch: 18, Test Loss(0.280994)
# Epoch:  19
# Epoch: 19, Test Loss(0.668607)
# Epoch:  20
# Epoch: 20, Train Loss Decreased!! (4.166647-->3.549306)
# Epoch: 20, Test Loss(0.350349)
# Epoch:  21
# Epoch: 21, Test Loss(0.631525)
# Epoch:  22
# Epoch: 22, Test Loss(0.757739)
# Epoch:  23
# Epoch: 23, Test Loss(1.300629)
# Epoch:  24
# Epoch: 24, Test Loss(0.580620)
# Epoch:  25
# Epoch: 25, Test Loss(0.770910)
# Epoch:  26
# Epoch: 26, Test Loss(0.342277)
# Epoch:  27
# Epoch: 27, Test Loss(0.425731)
# Epoch:  28
# Epoch: 28, Test Loss(0.367376)
# Epoch:  29
# Epoch: 29, Test Loss(0.521378)
# Epoch:  30
# Epoch: 30, Test Loss(0.644786)
# Epoch:  31
# Epoch: 31, Test Loss(1.089659)
# Epoch:  32
# Epoch: 32, Test Loss(1.348140)
# Epoch:  33
# Epoch: 33, Test Loss(2.692956)
# Epoch:  34
# Epoch: 34, Test Loss(2.412715)
# Epoch:  35
# Epoch: 35, Test Loss(0.876244)
# Epoch:  36
# Epoch: 36, Test Loss(0.923910)
# Epoch:  37
# Epoch: 37, Train Loss Decreased!! (3.549306-->2.388163)
# Epoch: 37, Test Loss(0.225260)
# Epoch:  38
# Epoch: 38, Train Loss Decreased!! (2.388163-->0.977335)
# Epoch: 38, Test Loss(0.104871)
# Epoch:  39
# Epoch: 39, Train Loss Decreased!! (0.977335-->0.581237)
# Epoch: 39, Test Loss(0.071509)
# Epoch:  40
# Epoch: 40, Train Loss Decreased!! (0.581237-->0.514499)
# Epoch: 40, Test Loss(0.064586)
# Epoch:  41
# Epoch: 41, Test Loss(0.087483)
# Epoch:  42
# Epoch: 42, Train Loss Decreased!! (0.514499-->0.397032)
# Epoch: 42, Test Loss(0.047118)
# Epoch:  43
# Epoch: 43, Train Loss Decreased!! (0.397032-->0.259344)
# Epoch: 43, Test Loss(0.047538)
# Epoch:  44
# Epoch: 44, Train Loss Decreased!! (0.259344-->0.230257)
# Epoch: 44, Test Loss(0.038368)
# Epoch:  45
# Epoch: 45, Train Loss Decreased!! (0.230257-->0.203820)
# Epoch: 45, Test Loss(0.041473)
# Epoch:  46
# Epoch: 46, Train Loss Decreased!! (0.203820-->0.201126)
# Epoch: 46, Test Loss(0.032026)
# Epoch:  47
# Epoch: 47, Train Loss Decreased!! (0.201126-->0.171642)
# Epoch: 47, Test Loss(0.029196)
# Epoch:  48
# Epoch: 48, Test Loss(0.030902)
# Epoch:  49
# Epoch: 49, Test Loss(0.026521)
# Epoch:  50
# Epoch: 50, Train Loss Decreased!! (0.171642-->0.146563)
# Epoch: 50, Test Loss(0.024340)
# Epoch:  51
# Epoch: 51, Train Loss Decreased!! (0.146563-->0.135299)
# Epoch: 51, Test Loss(0.023634)
# Epoch:  52
# Epoch: 52, Train Loss Decreased!! (0.135299-->0.130697)
# Epoch: 52, Test Loss(0.021880)
# Epoch:  53
# Epoch: 53, Train Loss Decreased!! (0.130697-->0.121971)
# Epoch: 53, Test Loss(0.020609)
# Epoch:  54
# Epoch: 54, Train Loss Decreased!! (0.121971-->0.118598)
# Epoch: 54, Test Loss(0.020552)
# Epoch:  55
# Epoch: 55, Test Loss(0.019230)
# Epoch:  56
# Epoch: 56, Train Loss Decreased!! (0.118598-->0.106470)
# Epoch: 56, Test Loss(0.018765)
# Epoch:  57
# Epoch: 57, Train Loss Decreased!! (0.106470-->0.103657)
# Epoch: 57, Test Loss(0.027413)
# Epoch:  58
# Epoch: 58, Train Loss Decreased!! (0.103657-->0.099397)
# Epoch: 58, Test Loss(0.016756)
# Epoch:  59
# Epoch: 59, Train Loss Decreased!! (0.099397-->0.093178)
# Epoch: 59, Test Loss(0.015848)
# Epoch:  60
# Epoch: 60, Train Loss Decreased!! (0.093178-->0.092528)
# Epoch: 60, Test Loss(0.015739)
# Epoch:  61
# Epoch: 61, Train Loss Decreased!! (0.092528-->0.086316)
# Epoch: 61, Test Loss(0.014761)
# Epoch:  62
# Epoch: 62, Train Loss Decreased!! (0.086316-->0.081790)
# Epoch: 62, Test Loss(0.013878)
# Epoch:  63
# Epoch: 63, Test Loss(0.013731)
# Epoch:  64
# Epoch: 64, Train Loss Decreased!! (0.081790-->0.077187)
# Epoch: 64, Test Loss(0.012566)
# Epoch:  65
# Epoch: 65, Train Loss Decreased!! (0.077187-->0.072565)
# Epoch: 65, Test Loss(0.012029)
# Epoch:  66
# Epoch: 66, Train Loss Decreased!! (0.072565-->0.069484)
# Epoch: 66, Test Loss(0.011493)
# Epoch:  67
# Epoch: 67, Test Loss(0.012297)
# Epoch:  68
# Epoch: 68, Train Loss Decreased!! (0.069484-->0.069388)
# Epoch: 68, Test Loss(0.010903)
# Epoch:  69
# Epoch: 69, Train Loss Decreased!! (0.069388-->0.062863)
# Epoch: 69, Test Loss(0.010118)
# Epoch:  70
# Epoch: 70, Train Loss Decreased!! (0.062863-->0.059704)
# Epoch: 70, Test Loss(0.009655)
# Epoch:  71
# Epoch: 71, Train Loss Decreased!! (0.059704-->0.057293)
# Epoch: 71, Test Loss(0.009238)
# Epoch:  72
# Epoch: 72, Test Loss(0.009542)
# Epoch:  73
# Epoch: 73, Train Loss Decreased!! (0.057293-->0.055425)
# Epoch: 73, Test Loss(0.008911)
# Epoch:  74
# Epoch: 74, Train Loss Decreased!! (0.055425-->0.051888)
# Epoch: 74, Test Loss(0.008288)
# Epoch:  75
# Epoch: 75, Train Loss Decreased!! (0.051888-->0.049268)
# Epoch: 75, Test Loss(0.007950)
# Epoch:  76
# Epoch: 76, Train Loss Decreased!! (0.049268-->0.047796)
# Epoch: 76, Test Loss(0.007646)
# Epoch:  77
# Epoch: 77, Train Loss Decreased!! (0.047796-->0.046235)
# Epoch: 77, Test Loss(0.007463)
# Epoch:  78
# Epoch: 78, Train Loss Decreased!! (0.046235-->0.044565)
# Epoch: 78, Test Loss(0.007333)
# Epoch:  79
# Epoch: 79, Test Loss(0.007329)
# Epoch:  80
# Epoch: 80, Test Loss(0.006745)
# Epoch:  81
# Epoch: 81, Train Loss Decreased!! (0.044565-->0.040081)
# Epoch: 81, Test Loss(0.006405)
# Epoch:  82
# Epoch: 82, Train Loss Decreased!! (0.040081-->0.038261)
# Epoch: 82, Test Loss(0.006125)
# Epoch:  83
# Epoch: 83, Train Loss Decreased!! (0.038261-->0.036610)
# Epoch: 83, Test Loss(0.005878)
# Epoch:  84
# Epoch: 84, Train Loss Decreased!! (0.036610-->0.035180)
# Epoch: 84, Test Loss(0.005634)
# Epoch:  85
# Epoch: 85, Train Loss Decreased!! (0.035180-->0.033771)
# Epoch: 85, Test Loss(0.005426)
# Epoch:  86
# Epoch: 86, Train Loss Decreased!! (0.033771-->0.032470)
# Epoch: 86, Test Loss(0.005230)
# Epoch:  87
# Epoch: 87, Test Loss(0.007645)
# Epoch:  88
# Epoch: 88, Train Loss Decreased!! (0.032470-->0.031808)
# Epoch: 88, Test Loss(0.004993)
# Epoch:  89
# Epoch: 89, Train Loss Decreased!! (0.031808-->0.029410)
# Epoch: 89, Test Loss(0.004747)
# Epoch:  90
# Epoch: 90, Test Loss(0.006791)
# Epoch:  91
# Epoch: 91, Test Loss(0.005165)
# Epoch:  92
# Epoch: 92, Test Loss(0.004725)
# Epoch:  93
# Epoch: 93, Train Loss Decreased!! (0.029410-->0.027016)
# Epoch: 93, Test Loss(0.004430)
# Epoch:  94
# Epoch: 94, Train Loss Decreased!! (0.027016-->0.026082)
# Epoch: 94, Test Loss(0.004700)
# Epoch:  95
# Epoch: 95, Test Loss(0.004562)
# Epoch:  96
# Epoch: 96, Test Loss(0.004671)
# Epoch:  97
# Epoch: 97, Train Loss Decreased!! (0.026082-->0.026043)
# Epoch: 97, Test Loss(0.003799)
# Epoch:  98
# Epoch: 98, Train Loss Decreased!! (0.026043-->0.024327)
# Epoch: 98, Test Loss(0.003821)
# Epoch:  99
# Epoch: 99, Test Loss(0.016895)
# Epoch:  100
# 100%|██████████| 5/5 [23:49<00:00, 285.95s/it]
# Epoch: 100, Test Loss(0.003452)

# %%
outputs_np = outputs.detach().cpu().numpy()
targets_np = targets.detach().cpu().numpy()
firing_rates_np = firing_rates.detach().cpu().numpy()

# %%
outputs_test_np = outputs_test.detach().cpu().numpy()
targets_test_np = targets_test.detach().cpu().numpy()
firing_rates_test_np = firing_rates_test.detach().cpu().numpy()

# %%
kk = 10 ## all zeros freaks it out

plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(targets_np[kk],label='Ground truth',color='k')
plt.plot(outputs_np[kk],label='Recon',color='r')
plt.legend()
plt.title('Train')

plt.subplot(122)
plt.plot(targets_test_np[kk],label='Ground truth',color='k')
plt.plot(outputs_test_np[kk],label='Recon',color='r')
plt.legend()
plt.title('Test')
# Out:
# Text(0.5, 1.0, 'Test')

# %%
weights_final = {}
for cntr in range(nRuns):
    weights_final[cntr] = model[cntr].rnn.weight_hh_l0.detach().cpu().numpy()

# %%
kk = 0

plt.figure(figsize=(10,4))
plt.subplot(121)
plt.imshow(weights_init[kk])
plt.colorbar()
plt.title('Initial Weights')

plt.subplot(122)
plt.imshow(weights_final[kk])
plt.colorbar()
plt.title('Final Weights')
# Out:
# Text(0.5, 1.0, 'Final Weights')

# %%
plt.hist(weights_final[kk])
plt.title('Distribution of Weights: Conventional Backprop')
plt.xlabel('Weights: Final')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
mean_train_losses = np.mean(train_losses, axis=0)
variance_train_losses = np.var(train_losses, axis=0)

mean_test_losses = np.mean(test_losses, axis=0)
variance_test_losses = np.var(test_losses, axis=0)

# %%
# Define x-axis (epochs)
x = np.arange(num_epochs)

# Plot shaded error bar using Seaborn
plt.figure(figsize=(10, 5))
# sns.lineplot(x=x, y=mean_train_losses, color='r')
# plt.fill_between(x, mean_train_losses - np.sqrt(variance_train_losses), mean_train_losses + np.sqrt(variance_train_losses),
#                  color='r', alpha=0.2)

sns.lineplot(x=x, y=mean_test_losses, color='r')
plt.fill_between(x, mean_test_losses - np.sqrt(variance_test_losses), mean_test_losses + np.sqrt(variance_test_losses),
                 color='r', alpha=0.2)

# Add labels and title
plt.xlabel('Epochs')
plt.ylabel('Test Error')
plt.title('Loss Curve: Conventional Backprop')

# Show plot
plt.show()

# %% [markdown]
# #### Saves

# %%
## Save train, test losses + accuracies
np.save('flipflop_train_losses_conventional_backprop',train_losses)
np.save('flipflop_test_losses_conventional_backprop',test_losses)

# %%
# Save dictionary to a Numpy .npz file
np.savez('flipflop_weights_init_conventional.npz', weights_init, pickle=True)
np.savez('flipflop_weights_final_conventional.npz', weights_final, pickle=True)
